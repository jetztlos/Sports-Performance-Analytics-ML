# %% [markdown]
# ## Part 1- Data Coding and Merging

# %%
#Import Libraries

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1.	Import the “NHL_Team.csv” data file and name the dataframe as “NHL_Team” in Jupyter Notebook. 
# a) Delete the following variables: “Unnamed:0”, “abbr”, “tname”, “lname”, and “sname”. 
# b) Rename the variable “name” to “team_name”.

# %%
# Import NHL Team Data and Display
NHL_Team=pd.read_csv("Assignment Data/Week 2/NHL_team.csv")
display(NHL_Team)
# Out:
#     Unnamed: 0    tid                   name           tname         lname  \
# 0            1      1    Toronto Maple Leafs     Maple Leafs       Toronto
# 1            2      2     Montréal Canadiens       Canadiens      Montréal
# 2            3      4          Winnipeg Jets            Jets      Winnipeg
# 3            4      5    Washington Capitals        Capitals    Washington
# 4            5      6     Chicago Blackhawks      Blackhawks       Chicago
# 5            6      7        St. Louis Blues           Blues     St. Louis
# 6            7      8    Pittsburgh Penguins        Penguins    Pittsburgh
# 7            8     10        Edmonton Oilers          Oilers      Edmonton
# 8            9     11         Calgary Flames          Flames       Calgary
# 9           10     14    Philadelphia Flyers          Flyers  Philadelphia
# 10          11     16        San Jose Sharks          Sharks      San Jose
# 11          12     17         Buffalo Sabres          Sabres       Buffalo
# 12          13     18      Detroit Red Wings       Red Wings       Detroit
# 13          14     19    Nashville Predators       Predators     Nashville
# 14          15     20          Boston Bruins          Bruins        Boston
# 15          16     21          Anaheim Ducks           Ducks       Anaheim
# 16          17     22     Colorado Avalanche       Avalanche      Colorado
# 17          18     25    Tampa Bay Lightning       Lightning     Tampa Bay
# 18          19     28       New York Rangers         Rangers      New York
# 19          20     29      New Jersey Devils          Devils    New Jersey
# 20          21     32        Ottawa Senators        Senators        Ottawa
# 21          22     35         Minnesota Wild            Wild     Minnesota
# 22          23     41      Los Angeles Kings           Kings   Los Angeles
# 23          24     43        Arizona Coyotes         Coyotes       Arizona
# 24          25     45       Florida Panthers        Panthers       Florida
# 25          26     46           Dallas Stars           Stars        Dallas
# 26          27     50        Phoenix Coyotes         Coyotes       Phoenix
# 27          28     51     New York Islanders       Islanders      New York
# 28          29     52  Columbus Blue Jackets    Blue Jackets      Columbus
# 29          30     53      Vancouver Canucks         Canucks     Vancouver
# 30          31     59   Vegas Golden Knights  Golden Knights         Vegas
# 31          32     66    Carolina Hurricanes      Hurricanes      Carolina
# 32          33  11366      Atlanta Thrashers       Thrashers       Atlanta
#
#    tricode abbr         sname
# 0      TOR  TOR       Toronto
# 1      MTL  MTL      Montréal
# 2      WPG  WPG      Winnipeg
# 3      WSH  WSH    Washington
# 4      CHI  CHI       Chicago
# 5      STL  STL      St Louis
# 6      PIT  PIT    Pittsburgh
# 7      EDM  EDM      Edmonton
# 8      CGY  CGY       Calgary
# 9      PHI  PHI  Philadelphia
# 10     SJS  SJS      San Jose
# 11     BUF  BUF       Buffalo
# 12     DET  DET       Detroit
# 13     NSH  NSH     Nashville
# 14     BOS  BOS        Boston
# 15     ANA  ANA       Anaheim
# 16     COL  COL      Colorado
# 17     TBL  TBL     Tampa Bay
# 18     NYR  NYR    NY Rangers
# 19     NJD  NJD    New Jersey
# 20     OTT  OTT        Ottawa
# 21     MIN  MIN     Minnesota
# 22     LAK  LAK   Los Angeles
# 23     ARI  ARI       Arizona
# 24     FLA  FLA       Florida
# 25     DAL  DAL        Dallas
# 26     PHX  PHX       Phoenix
# 27     NYI  NYI  NY Islanders
# 28     CBJ  CBJ      Columbus
# 29     VAN  VAN     Vancouver
# 30     VGK  VGK         Vegas
# 31     CAR  CAR      Carolina
# 32     ATL  ATL       Atlanta

# %%
# Delete the "Unnamed:0", "abbr", "tname", "lname", and "sname" variables
NHL_Team.drop(['Unnamed: 0', 'abbr', 'tname', 'lname', 'sname'], axis=1, inplace=True)
NHL_Team.head()
# Out:
#    tid                 name tricode
# 0    1  Toronto Maple Leafs     TOR
# 1    2   Montréal Canadiens     MTL
# 2    4        Winnipeg Jets     WPG
# 3    5  Washington Capitals     WSH
# 4    6   Chicago Blackhawks     CHI

# %%
# Rename the variable "name" to "team_name" in the NHL_Team dataframe
NHL_Team.rename(columns={'name':'team_name'}, inplace=True)
NHL_Team.head()
# Out:
#    tid            team_name tricode
# 0    1  Toronto Maple Leafs     TOR
# 1    2   Montréal Canadiens     MTL
# 2    4        Winnipeg Jets     WPG
# 3    5  Washington Capitals     WSH
# 4    6   Chicago Blackhawks     CHI

# %%
# 2.	Import the “NHL_competition.csv” data file and name the dataframe as “NHL_Competition” in Jupyter Notebook. 
# a) Delete the following variables: “Unnamed: 0”, “tz”, “start”, and “end” 
# b) Rename the variable “name” to “competition_name”.

# %%
#Import NHL Competition Data and Display Head
NHL_Competition=pd.read_csv("Assignment Data/Week 2/NHL_competition.csv")
NHL_Competition.head()
# Out:
#    Unnamed: 0  comp_id  year  type                     name  tz  start  end
# 0           1        1  2013     2  2013 NHL Regular Season  ET    NaN  NaN
# 1           2        2  2017     2  2017 NHL Regular Season  ET    NaN  NaN
# 2           3     2453  2013     3         2013 NHL Playoff  ET    NaN  NaN
# 3           4     2541  2017     3         2017 NHL Playoff  ET    NaN  NaN
# 4           5     2661  2012     2  2012 NHL Regular Season  ET    NaN  NaN

# %%
# Delete the "Unnamed: 0", "start" and "end" variables
NHL_Competition.drop(['Unnamed: 0','tz','start','end'], axis=1, inplace=True)

# %%
# Rename the variable "name" to "competition_name" in the NHL_Competition dataframe
NHL_Competition.rename(columns={'name':'competition_name'}, inplace=True)
NHL_Competition.head()
# Out:
#    comp_id  year  type         competition_name
# 0        1  2013     2  2013 NHL Regular Season
# 1        2  2017     2  2017 NHL Regular Season
# 2     2453  2013     3         2013 NHL Playoff
# 3     2541  2017     3         2017 NHL Playoff
# 4     2661  2012     2  2012 NHL Regular Season

# %%
# 3.	Import the “NHL_game.csv” data file and name the dataframe as “NHL_Game” in Jupyter Notebook. 
# a) Delete the following variables: “X”, “period”, and “status”.

# %%
#Import NHL Game Data and Display Head
NHL_Game=pd.read_csv("Assignment Data/Week 2/NHL_game.csv")
NHL_Game.head()
# Out:
#    X  gid  comp_id        date  ascore  hscore  period  status home_away  tid
# 0  1   37        2   10/7/2017     NaN     NaN     NaN     NaN      away   25
# 1  2   67        2   10/9/2017     NaN     NaN     NaN     NaN      away   29
# 2  3  154        1  10/14/2013     NaN     NaN     NaN     NaN      away   29
# 3  4  278        1  10/24/2013     NaN     NaN     NaN     NaN      away   53
# 4  5  291        1  10/25/2013     NaN     NaN     NaN     NaN      away    5

# %%
# Delete the "X","period", and "status" variables
NHL_Game.drop(['X','period','status'], axis=1, inplace=True)
NHL_Game.head()
# Out:
#    gid  comp_id        date  ascore  hscore home_away  tid
# 0   37        2   10/7/2017     NaN     NaN      away   25
# 1   67        2   10/9/2017     NaN     NaN      away   29
# 2  154        1  10/14/2013     NaN     NaN      away   29
# 3  278        1  10/24/2013     NaN     NaN      away   53
# 4  291        1  10/25/2013     NaN     NaN      away    5

# %%
# 4.	Merge the dataframe “NHL_Team” into the dataframe “NHL_Game” by “tid.” Continue to name the merged dataframe as “NHL_Game.”

# %%
NHL_Game=pd.merge(NHL_Game, NHL_Team, on=['tid'])
NHL_Game.head()
# Out:
#     gid  comp_id       date  ascore  hscore home_away  tid  \
# 0    37        2  10/7/2017     NaN     NaN      away   25
# 1  1623        2   2/6/2018     NaN     NaN      away   25
# 2  2550     2541  4/23/2018     NaN     NaN      away   25
# 3  2649     2541   5/8/2018     NaN     NaN      away   25
# 4  3304     2661   3/6/2013     NaN     NaN      away   25
#
#              team_name tricode
# 0  Tampa Bay Lightning     TBL
# 1  Tampa Bay Lightning     TBL
# 2  Tampa Bay Lightning     TBL
# 3  Tampa Bay Lightning     TBL
# 4  Tampa Bay Lightning     TBL

# %%
# 5.	Merge the dataframe “NHL_Competition” into the dataframe “NHL_Game” by “comp_id.” Continue to name the merged dataframe as “NHL_Game.”

# %%
NHL_Game=pd.merge(NHL_Game, NHL_Competition, on=['comp_id'])
NHL_Game.head()
# Out:
#     gid  comp_id        date  ascore  hscore home_away  tid  \
# 0    37        2   10/7/2017     NaN     NaN      away   25
# 1  1623        2    2/6/2018     NaN     NaN      away   25
# 2   981        2  12/15/2017     4.0     1.0      away   25
# 3  1607        2    2/4/2018     4.0     2.0      away   25
# 4  2403        2   3/30/2018     7.0     3.0      away   25
#
#              team_name tricode  year  type         competition_name
# 0  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season
# 1  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season
# 2  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season
# 3  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season
# 4  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season

# %%
# 6.	In the merged “NHL_Game” dataframe, create a variable “hgd” to indicate the goal difference between home and away score (hscore – ascore) and delete observations with missing value in the variable “hgd”.

# %%
NHL_Game['hgd']=NHL_Game['hscore']-NHL_Game['ascore']
NHL_Game.head()
# Out:
#     gid  comp_id        date  ascore  hscore home_away  tid  \
# 0    37        2   10/7/2017     NaN     NaN      away   25
# 1  1623        2    2/6/2018     NaN     NaN      away   25
# 2   981        2  12/15/2017     4.0     1.0      away   25
# 3  1607        2    2/4/2018     4.0     2.0      away   25
# 4  2403        2   3/30/2018     7.0     3.0      away   25
#
#              team_name tricode  year  type         competition_name  hgd
# 0  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  NaN
# 1  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  NaN
# 2  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -3.0
# 3  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -2.0
# 4  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -4.0

# %%
# 7.	Drop all observations with missing values, if there is still any, from the “NHL_Game” dataframe.

# %%
# Delete observations with missing value in the variable "hgd"
NHL_Game=NHL_Game[pd.notnull(NHL_Game["hgd"])]
NHL_Game.head()
# Out:
#     gid  comp_id        date  ascore  hscore home_away  tid  \
# 2   981        2  12/15/2017     4.0     1.0      away   25
# 3  1607        2    2/4/2018     4.0     2.0      away   25
# 4  2403        2   3/30/2018     7.0     3.0      away   25
# 5  1541        2   1/31/2018     1.0     3.0      away   25
# 6  1243        2    1/5/2018     1.0     2.0      away   25
#
#              team_name tricode  year  type         competition_name  hgd
# 2  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -3.0
# 3  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -2.0
# 4  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -4.0
# 5  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  2.0
# 6  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0

# %%
# Drop observations with missing values in the NHL_Game
NHL_Game=NHL_Game.dropna()
NHL_Game.head()
# Out:
#     gid  comp_id        date  ascore  hscore home_away  tid  \
# 2   981        2  12/15/2017     4.0     1.0      away   25
# 3  1607        2    2/4/2018     4.0     2.0      away   25
# 4  2403        2   3/30/2018     7.0     3.0      away   25
# 5  1541        2   1/31/2018     1.0     3.0      away   25
# 6  1243        2    1/5/2018     1.0     2.0      away   25
#
#              team_name tricode  year  type         competition_name  hgd
# 2  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -3.0
# 3  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -2.0
# 4  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -4.0
# 5  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  2.0
# 6  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0

# %%
# Number of observations and the number of variables in the NHL_Game data
NHL_Game.shape
# Out:
# (18506, 13)

# %%
# 8.	Convert the type of the “date” variable from “object” to “datetime.”

# %%
# Convert type of "date" variable from object to datetime
import datetime
NHL_Game['date']=pd.to_datetime(NHL_Game['date'])
NHL_Game['date'].head()
# Out:
# 2   2017-12-15
# 3   2018-02-04
# 4   2018-03-30
# 5   2018-01-31
# 6   2018-01-05
# Name: date, dtype: datetime64[ns]

# %%
# Time range of the NHL_Game dataframe
NHL_Game['date'].describe()
# Out:
# count                   18506
# unique                   1607
# top       2015-03-08 00:00:00
# freq                       30
# first     2010-10-07 00:00:00
# last      2018-06-08 00:00:00
# Name: date, dtype: object

# %%
# 9.	Sort the NHL games by “date” and show the first 15 observations.

# %%
# Sort the games by "date" and show the first 15 observations
NHL_Game.sort_values(by=['date'], ascending=[True]).head(15)
# Out:
#         gid  comp_id       date  ascore  hscore home_away    tid  \
# 8424   5666     5662 2010-10-07     4.0     3.0      away     66
# 9944   5664     5662 2010-10-07     3.0     2.0      home      8
# 9006   5664     5662 2010-10-07     3.0     2.0      away     14
# 9125   5666     5662 2010-10-07     4.0     3.0      home     35
# 8814   5662     5662 2010-10-07     2.0     3.0      home      1
# 8697   5662     5662 2010-10-07     2.0     3.0      away      2
# 9742   5672     5662 2010-10-08     3.0     2.0      away     16
# 9546   5681     5662 2010-10-08     2.0     1.0      home     32
# 8975   5679     5662 2010-10-08     0.0     4.0      home     18
# 10004  5668     5662 2010-10-08     3.0     4.0      away      6
# 9261   5679     5662 2010-10-08     0.0     4.0      away     21
# 8473   5677     5662 2010-10-08     1.0     2.0      home     66
# 9087   5677     5662 2010-10-08     1.0     2.0      away     35
# 7974   5674     5662 2010-10-08     4.0     3.0      home     29
# 10276  5683     5662 2010-10-08     2.0     4.0      home  11366
#
#                  team_name tricode  year  type         competition_name  hgd
# 8424   Carolina Hurricanes     CAR  2010     2  2010 NHL Regular Season -1.0
# 9944   Pittsburgh Penguins     PIT  2010     2  2010 NHL Regular Season -1.0
# 9006   Philadelphia Flyers     PHI  2010     2  2010 NHL Regular Season -1.0
# 9125        Minnesota Wild     MIN  2010     2  2010 NHL Regular Season -1.0
# 8814   Toronto Maple Leafs     TOR  2010     2  2010 NHL Regular Season  1.0
# 8697    Montréal Canadiens     MTL  2010     2  2010 NHL Regular Season  1.0
# 9742       San Jose Sharks     SJS  2010     2  2010 NHL Regular Season -1.0
# 9546       Ottawa Senators     OTT  2010     2  2010 NHL Regular Season -1.0
# 8975     Detroit Red Wings     DET  2010     2  2010 NHL Regular Season  4.0
# 10004   Chicago Blackhawks     CHI  2010     2  2010 NHL Regular Season  1.0
# 9261         Anaheim Ducks     ANA  2010     2  2010 NHL Regular Season  4.0
# 8473   Carolina Hurricanes     CAR  2010     2  2010 NHL Regular Season  1.0
# 9087        Minnesota Wild     MIN  2010     2  2010 NHL Regular Season  1.0
# 7974     New Jersey Devils     NJD  2010     2  2010 NHL Regular Season -1.0
# 10276    Atlanta Thrashers     ATL  2010     2  2010 NHL Regular Season  2.0

# %%
# 10.	Create two dataframes that separate the “NHL_Game” dataframe by home and away games. Name them “NHL_Home” and “NHL_Away”, respectively. 
# a) Rename variables: 
#     i) For away games, rename “ascore” to “goals_for”; rename “hscore” to “goals_against” 
#     ii) For home games, rename “hscore” to “goals_for”; rename “ascore” to “goals_against” 
# b) Create a “win” variable that equals to 1 if the team won the game; 0 if the team lost the game; and 0.5 if it was a draw.

# %%
# Separate the NHL_Game dataframe for home games and away games. Name them "NHL_Home" and "NHL_Away", respectively
NHL_Home=NHL_Game[(NHL_Game.home_away == 'home')].copy()
NHL_Home.head()
# Out:
#      gid  comp_id       date  ascore  hscore home_away  tid  \
# 41  2254        2 2018-03-20     3.0     4.0      home   25
# 42  2050        2 2018-03-07     4.0     5.0      home   25
# 43   844        2 2017-12-06     2.0     6.0      home   25
# 44   659        2 2017-11-23     2.0     3.0      home   25
# 45  2147        2 2018-03-13     7.0     4.0      home   25
#
#               team_name tricode  year  type         competition_name  hgd
# 41  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0
# 42  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0
# 43  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  4.0
# 44  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0
# 45  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -3.0

# %%
NHL_Away=NHL_Game[(NHL_Game.home_away=='away')].copy()
NHL_Away.head()
# Out:
#     gid  comp_id       date  ascore  hscore home_away  tid  \
# 2   981        2 2017-12-15     4.0     1.0      away   25
# 3  1607        2 2018-02-04     4.0     2.0      away   25
# 4  2403        2 2018-03-30     7.0     3.0      away   25
# 5  1541        2 2018-01-31     1.0     3.0      away   25
# 6  1243        2 2018-01-05     1.0     2.0      away   25
#
#              team_name tricode  year  type         competition_name  hgd
# 2  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -3.0
# 3  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -2.0
# 4  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -4.0
# 5  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  2.0
# 6  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0

# %%
# Rename variables:
#     - For away games, rename "ascore" to "goals_for" and "hscore" to "goals_against"
#     - For home games,rename "hscore" to "goals_for" and "ascore" to "goals_against"
NHL_Away.rename(columns={'ascore':'goals_for'}, inplace=True)
NHL_Away.rename(columns={'hscore':'goals_against'}, inplace=True)

NHL_Home.rename(columns={'hscore':'goals_for'}, inplace=True)
NHL_Home.rename(columns={'ascore':'goals_against'}, inplace=True)

NHL_Away.head()
# Out:
#     gid  comp_id       date  goals_for  goals_against home_away  tid  \
# 2   981        2 2017-12-15        4.0            1.0      away   25
# 3  1607        2 2018-02-04        4.0            2.0      away   25
# 4  2403        2 2018-03-30        7.0            3.0      away   25
# 5  1541        2 2018-01-31        1.0            3.0      away   25
# 6  1243        2 2018-01-05        1.0            2.0      away   25
#
#              team_name tricode  year  type         competition_name  hgd
# 2  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -3.0
# 3  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -2.0
# 4  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season -4.0
# 5  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  2.0
# 6  Tampa Bay Lightning     TBL  2017     2  2017 NHL Regular Season  1.0

# %%
# Create a "win" variable equals to 1 if the team won the game; 0 if the team lost the game; and 0.5 if it was a draw.
#     - For home team, win=1 if the variable "hgd" is positive
#     - For away team, win=1 if the variable "hgd" is negative
NHL_Home.loc[(NHL_Home['hgd']>0, 'win')] = 1
NHL_Home.loc[(NHL_Home['hgd']<0, 'win')] = 0
NHL_Home.loc[(NHL_Home['hgd']==0, 'win')] = 0.5

NHL_Away.loc[(NHL_Away['hgd']<0, 'win')] = 1
NHL_Away.loc[(NHL_Away['hgd']>0, 'win')] = 0
NHL_Away.loc[(NHL_Away['hgd']==0, 'win')] = 0.5

# %%
# 11.	Append the “NHL_Home” and “NHL_Away” dataframes to be the new “NHL_Game” dataframe.

# %%
# Append the NHL_Home and NHL_Away dataframes as the new NHL_Game dataframe
NHL_Game=pd.concat([NHL_Home, NHL_Away], axis=0)
display(NHL_Game)
# Out:
#        comp_id         competition_name       date   gid  goals_against  \
# 41           2  2017 NHL Regular Season 2018-03-20  2254            3.0
# 42           2  2017 NHL Regular Season 2018-03-07  2050            4.0
# 43           2  2017 NHL Regular Season 2017-12-06   844            2.0
# 44           2  2017 NHL Regular Season 2017-11-23   659            2.0
# 45           2  2017 NHL Regular Season 2018-03-13  2147            7.0
# 46           2  2017 NHL Regular Season 2017-11-04   407            4.0
# 47           2  2017 NHL Regular Season 2018-04-01  2439            4.0
# 48           2  2017 NHL Regular Season 2018-02-18  1797            4.0
# 49           2  2017 NHL Regular Season 2017-10-09    71            3.0
# 50           2  2017 NHL Regular Season 2017-11-17   567            1.0
# 51           2  2017 NHL Regular Season 2018-01-10  1316            4.0
# 52           2  2017 NHL Regular Season 2018-03-26  2346            4.0
# 53           2  2017 NHL Regular Season 2018-03-03  2003            6.0
# 54           2  2017 NHL Regular Season 2018-01-19  1404            4.0
# 55           2  2017 NHL Regular Season 2018-03-17  2205            3.0
# 56           2  2017 NHL Regular Season 2018-04-03  2468            0.0
# 57           2  2017 NHL Regular Season 2018-02-11  1692            3.0
# 58           2  2017 NHL Regular Season 2017-10-21   228            1.0
# 59           2  2017 NHL Regular Season 2018-03-09  2076            3.0
# 60           2  2017 NHL Regular Season 2017-10-12   101            4.0
# 61           2  2017 NHL Regular Season 2017-12-22  1069            3.0
# 62           2  2017 NHL Regular Season 2017-11-19   602            5.0
# 63           2  2017 NHL Regular Season 2017-11-02   382            2.0
# 64           2  2017 NHL Regular Season 2017-12-29  1142            1.0
# 65           2  2017 NHL Regular Season 2017-12-24  1092            0.0
# 66           2  2017 NHL Regular Season 2017-12-10   900            3.0
# 67           2  2017 NHL Regular Season 2018-02-09  1660            2.0
# 68           2  2017 NHL Regular Season 2018-03-01  1961            2.0
# 69           2  2017 NHL Regular Season 2018-02-16  1767            1.0
# 70           2  2017 NHL Regular Season 2018-04-06  2507            5.0
# ...        ...                      ...        ...   ...            ...
# 18861     5181         2016 NHL Playoff 2017-05-04  5292            4.0
# 18873     5181         2016 NHL Playoff 2017-04-14  5229            4.0
# 18874     5181         2016 NHL Playoff 2017-04-20  5235            5.0
# 18875     5181         2016 NHL Playoff 2017-04-12  5226            3.0
# 18880     5181         2016 NHL Playoff 2017-04-13  5250            1.0
# 18881     5181         2016 NHL Playoff 2017-04-15  5252            1.0
# 18882     5181         2016 NHL Playoff 2017-05-03  5320            2.0
# 18883     5181         2016 NHL Playoff 2017-05-07  5324            3.0
# 18884     5181         2016 NHL Playoff 2017-04-22  5258            3.0
# 18885     5181         2016 NHL Playoff 2017-04-30  5318            3.0
# 18894     5181         2016 NHL Playoff 2017-04-15  5274            2.0
# 18895     5181         2016 NHL Playoff 2017-04-13  5272            2.0
# 18896     5181         2016 NHL Playoff 2017-04-21  5280            3.0
# 18901     5181         2016 NHL Playoff 2017-04-15  5199            4.0
# 18902     5181         2016 NHL Playoff 2017-04-21  5205            2.0
# 18903     5181         2016 NHL Playoff 2017-04-12  5197            1.0
# 18910     5181         2016 NHL Playoff 2017-05-24  5354            1.0
# 18911     5181         2016 NHL Playoff 2017-05-20  5350            2.0
# 18912     5181         2016 NHL Playoff 2017-05-10  5312            0.0
# 18913     5181         2016 NHL Playoff 2017-04-18  5233            5.0
# 18914     5181         2016 NHL Playoff 2017-06-04  5376            5.0
# 18915     5181         2016 NHL Playoff 2017-04-16  5231            4.0
# 18916     5181         2016 NHL Playoff 2017-04-30  5302            2.0
# 18917     5181         2016 NHL Playoff 2017-06-12  5382            0.0
# 18918     5181         2016 NHL Playoff 2017-06-06  5378            4.0
# 18919     5181         2016 NHL Playoff 2017-04-27  5300            2.0
# 18935     5181         2016 NHL Playoff 2017-04-18  5242            3.0
# 18936     5181         2016 NHL Playoff 2017-04-21  5245            4.0
# 18942     5181         2016 NHL Playoff 2017-04-16  5265            3.0
# 18943     5181         2016 NHL Playoff 2017-04-14  5262            3.0
#
#        goals_for  hgd home_away              team_name  tid tricode  type  \
# 41           4.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 42           5.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 43           6.0  4.0      home    Tampa Bay Lightning   25     TBL     2
# 44           3.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 45           4.0 -3.0      home    Tampa Bay Lightning   25     TBL     2
# 46           5.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 47           1.0 -3.0      home    Tampa Bay Lightning   25     TBL     2
# 48           3.0 -1.0      home    Tampa Bay Lightning   25     TBL     2
# 49           4.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 50           6.0  5.0      home    Tampa Bay Lightning   25     TBL     2
# 51           5.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 52           1.0 -3.0      home    Tampa Bay Lightning   25     TBL     2
# 53           8.0  2.0      home    Tampa Bay Lightning   25     TBL     2
# 54           1.0 -3.0      home    Tampa Bay Lightning   25     TBL     2
# 55           0.0 -3.0      home    Tampa Bay Lightning   25     TBL     2
# 56           4.0  4.0      home    Tampa Bay Lightning   25     TBL     2
# 57           4.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 58           7.0  6.0      home    Tampa Bay Lightning   25     TBL     2
# 59           5.0  2.0      home    Tampa Bay Lightning   25     TBL     2
# 60           5.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 61           5.0  2.0      home    Tampa Bay Lightning   25     TBL     2
# 62           3.0 -2.0      home    Tampa Bay Lightning   25     TBL     2
# 63           1.0 -1.0      home    Tampa Bay Lightning   25     TBL     2
# 64           3.0  2.0      home    Tampa Bay Lightning   25     TBL     2
# 65           3.0  3.0      home    Tampa Bay Lightning   25     TBL     2
# 66           4.0  1.0      home    Tampa Bay Lightning   25     TBL     2
# 67           5.0  3.0      home    Tampa Bay Lightning   25     TBL     2
# 68           1.0 -1.0      home    Tampa Bay Lightning   25     TBL     2
# 69           4.0  3.0      home    Tampa Bay Lightning   25     TBL     2
# 70           7.0  2.0      home    Tampa Bay Lightning   25     TBL     2
# ...          ...  ...       ...                    ...  ...     ...   ...
# 18861        1.0  3.0      away        Ottawa Senators   32     OTT     3
# 18873        1.0  3.0      away  Columbus Blue Jackets   52     CBJ     3
# 18874        2.0  3.0      away  Columbus Blue Jackets   52     CBJ     3
# 18875        1.0  2.0      away  Columbus Blue Jackets   52     CBJ     3
# 18880        2.0 -1.0      away        St. Louis Blues    7     STL     3
# 18881        2.0 -1.0      away        St. Louis Blues    7     STL     3
# 18882        1.0  1.0      away        St. Louis Blues    7     STL     3
# 18883        1.0  2.0      away        St. Louis Blues    7     STL     3
# 18884        4.0 -1.0      away        St. Louis Blues    7     STL     3
# 18885        1.0  2.0      away        St. Louis Blues    7     STL     3
# 18894        0.0  2.0      away        San Jose Sharks   16     SJS     3
# 18895        3.0 -1.0      away        San Jose Sharks   16     SJS     3
# 18896        3.0  0.0      away        San Jose Sharks   16     SJS     3
# 18901        3.0  1.0      away          Boston Bruins   20     BOS     3
# 18902        3.0 -1.0      away          Boston Bruins   20     BOS     3
# 18903        2.0 -1.0      away          Boston Bruins   20     BOS     3
# 18910        1.0  0.0      away    Pittsburgh Penguins    8     PIT     3
# 18911        3.0 -1.0      away    Pittsburgh Penguins    8     PIT     3
# 18912        2.0 -2.0      away    Pittsburgh Penguins    8     PIT     3
# 18913        4.0  1.0      away    Pittsburgh Penguins    8     PIT     3
# 18914        1.0  4.0      away    Pittsburgh Penguins    8     PIT     3
# 18915        5.0 -1.0      away    Pittsburgh Penguins    8     PIT     3
# 18916        6.0 -4.0      away    Pittsburgh Penguins    8     PIT     3
# 18917        2.0 -2.0      away    Pittsburgh Penguins    8     PIT     3
# 18918        1.0  3.0      away    Pittsburgh Penguins    8     PIT     3
# 18919        3.0 -1.0      away    Pittsburgh Penguins    8     PIT     3
# 18935        2.0  1.0      away     Chicago Blackhawks    6     CHI     3
# 18936        1.0  3.0      away     Chicago Blackhawks    6     CHI     3
# 18942        2.0  1.0      away         Calgary Flames   11     CGY     3
# 18943        2.0  1.0      away         Calgary Flames   11     CGY     3
#
#        win  year
# 41     1.0  2017
# 42     1.0  2017
# 43     1.0  2017
# 44     1.0  2017
# 45     0.0  2017
# 46     1.0  2017
# 47     0.0  2017
# 48     0.0  2017
# 49     1.0  2017
# 50     1.0  2017
# 51     1.0  2017
# 52     0.0  2017
# 53     1.0  2017
# 54     0.0  2017
# 55     0.0  2017
# 56     1.0  2017
# 57     1.0  2017
# 58     1.0  2017
# 59     1.0  2017
# 60     1.0  2017
# 61     1.0  2017
# 62     0.0  2017
# 63     0.0  2017
# 64     1.0  2017
# 65     1.0  2017
# 66     1.0  2017
# 67     1.0  2017
# 68     0.0  2017
# 69     1.0  2017
# 70     1.0  2017
# ...    ...   ...
# 18861  0.0  2016
# 18873  0.0  2016
# 18874  0.0  2016
# 18875  0.0  2016
# 18880  1.0  2016
# 18881  1.0  2016
# 18882  0.0  2016
# 18883  0.0  2016
# 18884  1.0  2016
# 18885  0.0  2016
# 18894  0.0  2016
# 18895  1.0  2016
# 18896  0.5  2016
# 18901  0.0  2016
# 18902  1.0  2016
# 18903  1.0  2016
# 18910  0.5  2016
# 18911  1.0  2016
# 18912  1.0  2016
# 18913  0.0  2016
# 18914  0.0  2016
# 18915  1.0  2016
# 18916  1.0  2016
# 18917  1.0  2016
# 18918  0.0  2016
# 18919  1.0  2016
# 18935  0.0  2016
# 18936  0.0  2016
# 18942  0.0  2016
# 18943  0.0  2016
#
# [18506 rows x 14 columns]

# %%
# Double check the number of observations in the new NHL_Game dataframe to make sure that we have successfully combined the two dataframes
NHL_Game.shape
# Out:
# (18506, 14)

# %%
# 12.	Generate a team level dataframe that aggregates the total number of games won, the total number of “goals_for” and “goals_against” for each team in each competition (i.e. grouped by tid, competition_name and type). 
# Name this new dataframe “NHL_Team_Stats”. Make sure to convert the indexes of the new dataframe back as  variables.

# %%
# Generate team level variable
# Create a team level dataframe called "NHL_Team_Stats" that aggregates the total number of games won, the total number of goals_for and goals_against for each team in each competition
NHL_Team_Stats = NHL_Game.groupby(['tid','competition_name','type'])['win','goals_for','goals_against'].sum()
NHL_Team_Stats.head()
# Out:
#                                    win  goals_for  goals_against
# tid competition_name        type
# 1   2010 NHL Regular Season 2     36.0      223.0          259.0
#     2011 NHL Regular Season 2     20.0      129.0          129.0
#     2012 NHL Playoff        3      3.0       18.0           22.0
#     2012 NHL Regular Season 2     25.0      144.0          129.0
#     2013 NHL Regular Season 2     38.0      231.0          250.0

# %%
# Convert the indexes back as variables in the NHL_Team_Stats dataframe
NHL_Team_Stats=NHL_Team_Stats.reset_index()
NHL_Team_Stats.head()
# Out:
#    tid         competition_name  type   win  goals_for  goals_against
# 0    1  2010 NHL Regular Season     2  36.0      223.0          259.0
# 1    1  2011 NHL Regular Season     2  20.0      129.0          129.0
# 2    1         2012 NHL Playoff     3   3.0       18.0           22.0
# 3    1  2012 NHL Regular Season     2  25.0      144.0          129.0
# 4    1  2013 NHL Regular Season     2  38.0      231.0          250.0

# %%
# 13.	Create a dataframe “NHL_Game_Count” that include the total number of games played by each team in each competition 
# (i.e. grouped by tid, competition_name and type). Name this new variable in the dataframe “game_count”.

# %%
# Create a dataframe "NHL_Game_Count" that include the total number of games played by each team in competition.
# Name this variable "game_count"
NHL_Game_Count=NHL_Game.groupby(['tid','competition_name','type']).size().reset_index(name='game_count')
display(NHL_Game_Count)
# Out:
#        tid         competition_name  type  game_count
# 0        1  2010 NHL Regular Season     2          82
# 1        1  2011 NHL Regular Season     2          40
# 2        1         2012 NHL Playoff     3           7
# 3        1  2012 NHL Regular Season     2          46
# 4        1  2013 NHL Regular Season     2          79
# 5        1  2014 NHL Regular Season     2          78
# 6        1  2015 NHL Regular Season     2          79
# 7        1         2016 NHL Playoff     3           6
# 8        1  2016 NHL Regular Season     2          82
# 9        1         2017 NHL Playoff     3           7
# 10       1  2017 NHL Regular Season     2          79
# 11       2         2010 NHL Playoff     3           7
# 12       2  2010 NHL Regular Season     2          79
# 13       2  2011 NHL Regular Season     2          39
# 14       2         2012 NHL Playoff     3           5
# 15       2  2012 NHL Regular Season     2          48
# 16       2         2013 NHL Playoff     3          17
# 17       2  2013 NHL Regular Season     2          81
# 18       2         2014 NHL Playoff     3          12
# 19       2  2014 NHL Regular Season     2          79
# 20       2  2015 NHL Regular Season     2          78
# 21       2         2016 NHL Playoff     3           6
# 22       2  2016 NHL Regular Season     2          82
# 23       2  2017 NHL Regular Season     2          79
# 24       4  2011 NHL Regular Season     2          40
# 25       4  2012 NHL Regular Season     2          47
# 26       4  2013 NHL Regular Season     2          81
# 27       4         2014 NHL Playoff     3           4
# 28       4  2014 NHL Regular Season     2          80
# 29       4  2015 NHL Regular Season     2          80
# ..     ...                      ...   ...         ...
# 339     52  2013 NHL Regular Season     2          81
# 340     52  2014 NHL Regular Season     2          80
# 341     52  2015 NHL Regular Season     2          77
# 342     52         2016 NHL Playoff     3           5
# 343     52  2016 NHL Regular Season     2          80
# 344     52         2017 NHL Playoff     3           6
# 345     52  2017 NHL Regular Season     2          81
# 346     53         2010 NHL Playoff     3          25
# 347     53  2010 NHL Regular Season     2          80
# 348     53         2011 NHL Playoff     3           5
# 349     53  2011 NHL Regular Season     2          41
# 350     53         2012 NHL Playoff     3           4
# 351     53  2012 NHL Regular Season     2          47
# 352     53  2013 NHL Regular Season     2          78
# 353     53         2014 NHL Playoff     3           6
# 354     53  2014 NHL Regular Season     2          80
# 355     53  2015 NHL Regular Season     2          80
# 356     53  2016 NHL Regular Season     2          80
# 357     53  2017 NHL Regular Season     2          81
# 358     59         2017 NHL Playoff     3          20
# 359     59  2017 NHL Regular Season     2          81
# 360     66  2010 NHL Regular Season     2          82
# 361     66  2011 NHL Regular Season     2          40
# 362     66  2012 NHL Regular Season     2          46
# 363     66  2013 NHL Regular Season     2          80
# 364     66  2014 NHL Regular Season     2          82
# 365     66  2015 NHL Regular Season     2          81
# 366     66  2016 NHL Regular Season     2          82
# 367     66  2017 NHL Regular Season     2          80
# 368  11366  2010 NHL Regular Season     2          79
#
# [369 rows x 4 columns]

# %%
# 14.	Merge dataframes. 
# a) Merge the “NHL_Game_Count” dataframe into the “NHL_Team_Stats” dataframe by “tid”, “competition_name”, and “type”. Continue to name the merged dataframe “NHL_Team_Stats”. 
# b) Merge the “NHL_Team” dataframe into the “NHL_Team_Stats” dataframe by “tid”. Continue to name the merged dataframe “NHL_Team_Stats”.

# %%
# Merge the NHL_Game_Count dataframe to the NHL_Team_Stats dataframe
NHL_Team_Stats=pd.merge(NHL_Team_Stats, NHL_Game_Count, on=['tid','competition_name','type'])
NHL_Team_Stats.head()
# Out:
#    tid         competition_name  type   win  goals_for  goals_against  \
# 0    1  2010 NHL Regular Season     2  36.0      223.0          259.0
# 1    1  2011 NHL Regular Season     2  20.0      129.0          129.0
# 2    1         2012 NHL Playoff     3   3.0       18.0           22.0
# 3    1  2012 NHL Regular Season     2  25.0      144.0          129.0
# 4    1  2013 NHL Regular Season     2  38.0      231.0          250.0
#
#    game_count
# 0          82
# 1          40
# 2           7
# 3          46
# 4          79

# %%
# Merge the NHL_Team dataframe to the NHL_Team_Stats dataframe
NHL_Team_Stats=pd.merge(NHL_Team_Stats, NHL_Team, on=['tid'])
NHL_Team_Stats.head()
# Out:
#    tid         competition_name  type   win  goals_for  goals_against  \
# 0    1  2010 NHL Regular Season     2  36.0      223.0          259.0
# 1    1  2011 NHL Regular Season     2  20.0      129.0          129.0
# 2    1         2012 NHL Playoff     3   3.0       18.0           22.0
# 3    1  2012 NHL Regular Season     2  25.0      144.0          129.0
# 4    1  2013 NHL Regular Season     2  38.0      231.0          250.0
#
#    game_count            team_name tricode
# 0          82  Toronto Maple Leafs     TOR
# 1          40  Toronto Maple Leafs     TOR
# 2           7  Toronto Maple Leafs     TOR
# 3          46  Toronto Maple Leafs     TOR
# 4          79  Toronto Maple Leafs     TOR

# %%
# 15.	Import the “pp.pk.ppgf.csv” data file and name the dataframe as “NHL_PPPK” in Jupyter Notebook. 
# Merge the “NHL_PPPK” dataframe into the “NHL_Team_Stats” dataframe by “tricode” and “competition_name”.

# %%
#Import NHL PPPK Data and Display Head
NHL_PPPK=pd.read_csv("Assignment Data/Week 2/pp.pk.ppgf.csv")
NHL_PPPK.head()
# Out:
#   tricode   pp   pk  ppgf  competition_name
# 0     ANA   35   27   9.0  2010 NHL Playoff
# 1     BOS  126  116  22.0  2010 NHL Playoff
# 2     BUF   48   46  13.0  2010 NHL Playoff
# 3     CHI   27   39   6.0  2010 NHL Playoff
# 4     DET   59   55   6.0  2010 NHL Playoff

# %%
# Merge the NHL_PPPK dataframe to the NHL_Team_Stats dataframe
NHL_Team_Stats=pd.merge(NHL_PPPK, NHL_Team_Stats, on=['tricode','competition_name'])
NHL_Team_Stats.head()
# Out:
#   tricode   pp   pk  ppgf  competition_name  tid  type   win  goals_for  \
# 0     ANA   35   27   9.0  2010 NHL Playoff   21     3   2.0       19.0
# 1     BOS  126  116  22.0  2010 NHL Playoff   20     3  16.0       76.0
# 2     BUF   48   46  13.0  2010 NHL Playoff   17     3   3.0       17.0
# 3     CHI   27   39   6.0  2010 NHL Playoff    6     3   3.0       22.0
# 4     DET   59   55   6.0  2010 NHL Playoff   18     3   7.0       36.0
#
#    goals_against  game_count           team_name
# 0           22.0           6       Anaheim Ducks
# 1           48.0          24       Boston Bruins
# 2           22.0           7      Buffalo Sabres
# 3           16.0           7  Chicago Blackhawks
# 4           27.0          11   Detroit Red Wings

# %%
# 16.	Create new variables in the “NHL_Team_Stats” dataframe. 
# a) Winning percentage (“win_pct”)=”win”/ total number of games played 
# b) Average goals for per game (“avg_gf”)=total number of goals for / total number of games played 
# c) Average goals against per game (“avg_ga”)=total number of goals against / total number of games played

# %%
# Create additional variables in the "NHL_Team_Stats" dataframe.
#     - winning percentage('win_pct')= 'win' / total number of games played
#     - average goals for per game ('avg_gf')= total number of goals for / total number of games played
#     - average goals against per game ('avg_ga') = total number of goals against / total number of games played
NHL_Team_Stats['win_pct']=NHL_Team_Stats['win']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_gf']=NHL_Team_Stats['goals_for']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_ga']=NHL_Team_Stats['goals_against']/NHL_Team_Stats['game_count']

# %%
NHL_Team_Stats['win_pct'].describe()
# Out:
# count    369.000000
# mean       0.472158
# std        0.134584
# min        0.000000
# 25%        0.406667
# 50%        0.500000
# 75%        0.562500
# max        0.800000
# Name: win_pct, dtype: float64

# %%
# 17.	In the “NHL_Competition” dataframe, the variable “type” indicates the type of competition: type=2 – regular season. 
#     Create a dataframe that contains team statistics for games only during regular seasons. Name this dataframe “NHL_Team_R_Stats”.

# %%
# In the NHL_Competition dataframe, the variable type indicates the type of competition. type=2 means it is regular season competition
# Create a dataframe (NHL_Team_R_Stats) that contains team statistics for games only during regular seasons
NHL_Team_R_Stats=NHL_Team_Stats[(NHL_Team_Stats.type == 2)]

# %% [markdown]
# ## Part 2 - Descriptive and Summary Analyses

# %%
# 1.	In the “NHL_Game” dataframe, calculate summary statistics for the  “goals_for” variable; 
# calculate summary statistics for the “goals_against” variable based on whether it is home or away game.

# %%
# Calculate summary statistics for the variable "goals_for"
NHL_Game['goals_for'].describe()
# Out:
# count    18506.000000
# mean         2.825894
# std          1.654729
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: goals_for, dtype: float64

# %%
# Calculate the summary statistics for the "goals_against" for the entire NHL_Game dataframe by whether the game is home or away
NHL_Game.groupby(['home_away'])['goals_against'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%   max
# home_away
# away       9253.0  2.961958  1.688463  0.0  2.0  3.0  4.0  10.0
# home       9253.0  2.689830  1.608916  0.0  1.0  3.0  4.0  10.0

# %%
# 2.	Create a histogram of the “goals_against” variable by whether the game is home or away 
# a) Make the color of the histogram green 
# b) Set the number of bins to be 20 
# c) Make sure the two sub-histograms share the same ranges for the x-axis and y-axis.

# %%
# Create a histogram of the "goals_against" variable by whether the game is home or away.
#     - Make the color of the histogram green
#     - Set the number of bins to be 20
#     - Make sure that the two sub-histograms share the same ranges for the x-axis and y-axis
# Save the histogram as "goals_against.png"
import matplotlib.pyplot as plt

NHL_Game.hist(by='home_away', column='goals_against', color='green', bins=20, sharex=True, sharey=True)
plt.savefig('goals_against.png')

# %% [markdown]
# ## Part 3 - Correlation Analyses

# %%
# 1.	In the “NHL_Team_R_Stats” dataframe, make a scatter plot to depict the relationship between the total number of goals for and the winning percentage. 
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis. 
# b) Add a regression line to the scatter plot. 
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11. 
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

# %%
# In the NHL_Team_R_Stats dataframe, make a scatter plot to depict the relationship between the total number of goals for and the winning percentage.
#     - Plot the total number of goals for on the x-axis and winning percentage on the y-axis
#     - Add a regression line to the scatter plot
#     - Make the title of the graph "Relationship between Goals for and Winning Percentage" and make the font size 11
#     - Label the x-axis as "Total Goals for" and label the y-axis as "Winning Percentage"
import seaborn as sns  

sns.lmplot(x='goals_for', y='win_pct', data=NHL_Team_R_Stats)
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.title("Relationship between Goals for and Winning Percentage", fontsize=11)
plt.savefig('scatter_gf_winpct.png')

# %%
# 2.	In the “NHL_Team_R_Stats” dataframe, calculate the correlation coefficient between total number of goals for and winning percentage.

# %%
# Calculate the correlation coefficient between total goals for and winning percentage     
NHL_Team_R_Stats['goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.31566456280848165

# %%
# 3.	Create a scatter plot of the total number of goals for and winning percentage similar to step 1 for regular season games. In this graph, group observations by “competition_name”. 
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis. 
# b) Add a regression line to the scatter plot. 
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11. 
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

# %%
# Create a scatter plot of total number of goals for and winning percentage, grouped by competition   
sns.lmplot(x='goals_for', y='win_pct', hue='competition_name', data=NHL_Team_R_Stats)
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.title("Relationship between Goals for and Winning Percentage", fontsize=11)
plt.savefig('scatter_gf_winpct_comp.png')

# %%
# 4.	For the “NHL_Team_R_Stats” dataframe, delete observations of 2011 and 2012 seasons. Continue to name the dataframe “NHL_Team_R_Stats”.

# %%
# Filter out the 2011 and 2012 seasons, continue to name this dataframe NHL_Team_R_Stats   
NHL_Team_R_Stats=NHL_Team_R_Stats[(NHL_Team_R_Stats.competition_name != '2011 NHL Regular Season')&\
                                  (NHL_Team_R_Stats.competition_name != '2012 NHL Regular Season')]

# %%
# 5.	In the new “NHL_Team_R_Stats” dataframe, create a scatter plot of total number of goals for and winning percentage. 
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis. 
# b) Add a regression line to the scatter plot. 
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11. 
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

# %%
# Create a scatter plot to depict the relationship between total goals for and winning percentage without seperating the data by competition  
sns.lmplot(x='goals_for', y='win_pct',  data=NHL_Team_R_Stats)
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.title("Relationship between Goals for and Winning Percentage", fontsize=11)
plt.savefig('scatter_gf_winpct_new.png')

# %%
# 6.	Calculate the correlation coefficient between total number of goals for and winning percentage in the updated “NHL_Team_R_Stats” dataframe.

# %%
# Calculate the correlation coefficient between goals for and winning percentage in the updated "NHL_Team_R_Stats" dataframe     
NHL_Team_R_Stats['goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.770625532180144

# %%
# 7.	Save dataframes as csv files. 
# a) Name the updated “NHL_Game” dataframe as “NHL_Game2”. 
# b) Name the “NHL_Team_Stats” dataframe as “NHL_Team_Stats”. 
# c) Name the “NHL_Team_R_Stats” dataframe as “NHL_Team_R_Stats”. 
# d) Make sure to exclude the index as a column in the csv files.

# %% [markdown]
# ## Uncomment this Section once your assignment is complete

# %%
# Save Dataframes as .csv files
NHL_Game.to_csv("NHL_Game2.csv", index=False)
NHL_Team_Stats.to_csv("NHL_Team_Stats.csv", index=False)
NHL_Team_R_Stats.to_csv("NHL_Team_R_Stats.csv", index=False)
